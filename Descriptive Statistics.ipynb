# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
cardio=pd.read_csv("I:/Data Science/Eduonix/Instructor - Prema Latha/Datasets-main/CardioGoodFitness-1.csv")

# %%
cardio.shape
# Out:
# (180, 9)

# %%
cardio.head(10)
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
cardio.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 166   TM798   29    Male         14     Partnered      7        5   85906
# 88    TM498   23    Male         14     Partnered      3        3   38658
# 162   TM798   28  Female         18     Partnered      6        5   92131
# 104   TM498   25    Male         14     Partnered      3        4   43206
# 82    TM498   20  Female         14     Partnered      3        3   34110
# 98    TM498   25  Female         14        Single      3        4   43206
# 49    TM195   28  Female         16     Partnered      3        3   51165
# 167   TM798   30  Female         16     Partnered      6        5   90886
# 172   TM798   34    Male         16        Single      5        5   92131
# 85    TM498   21    Male         16     Partnered      2        2   34110
#
#      Miles
# 166    300
# 88      85
# 162    180
# 104    106
# 82     106
# 98     127
# 49      56
# 167    280
# 172    150
# 85      42

# %%
cardio.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
cardio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
cardio.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
cardio.describe(include="all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
cardio["Product"].value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
sns.countplot(x="Product", data=cardio, palette="Paired")
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
cardio["Product"].nunique()
# Out:
# 3

# %%
cardio["Product"].unique()
# Out:
# array(['TM195', 'TM498', 'TM798'], dtype=object)

# %%
cardio["Product"].value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
### Gender
sns.countplot(x="Gender", data=cardio, palette="Set3")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
cardio["Gender"].nunique()
# Out:
# 2

# %%
cardio["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
cardio["Gender"].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
### Marital Status

sns.countplot(x="MaritalStatus", data=cardio)
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
cardio["MaritalStatus"].nunique()
# Out:
# 2

# %%
cardio["MaritalStatus"].unique()
# Out:
# array(['Single', 'Partnered'], dtype=object)

# %%
cardio["MaritalStatus"].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
cardio.hist()
plt.show()

# %%
## Histogram only works for integer and float data type. Object data type can't have mean and median
cardio.hist(figsize=(10,10), color="brown")
plt.show()

# %%
sns.distplot(cardio["Age"])
plt.show()

# %%
sns.boxplot(x="Age", data=cardio, palette="Paired")
plt.show()
## Box plot is also called five numbers summary --> min, max, Q1, Q2 (Median), Q3

# %%
## for above Age data
Q1=24
Q3=33
IQR=Q3-Q1
IQR
# Out:
# 9

# %%
Q1-1.5*IQR
# Out:
# 10.5

# %%
Q3+1.5*IQR
# Out:
# 46.5

# %%
cardio[cardio["Age"]>46.5]
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 78    TM195   47    Male         16     Partnered      4        3   56850
# 79    TM195   50  Female         16     Partnered      3        3   64809
# 139   TM498   48    Male         16     Partnered      2        3   57987
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 78      94
# 79      66
# 139     64
# 178    120
# 179    180

# %%
sns.countplot(x="Product", hue="Gender", data=cardio)
plt.show()

## Inference: TM195 and TM498 is used by both male and female whereas TM798 is mostly used by male

# %%
pd.crosstab(cardio["Product"],cardio["Gender"])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
sns.countplot(x="Product", hue="MaritalStatus", data=cardio, palette="Paired")
plt.show()

# %%
pd.crosstab(cardio["Product"],cardio["MaritalStatus"])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
sns.boxplot(x="Product",y="Age", data=cardio, palette="Set2")
plt.show()
## Middle age people are using TM798

# %%
sns.boxplot(x="Product",y="Income", data=cardio, palette="Set2")
plt.show()
## High income people are using TM798 whereas low income people are using TM195 and TM498

# %%
sns.pairplot(data=cardio)
plt.show()

# %%
corr=cardio.corr()
corr
### If value is close to 1, then it is good relation
### It close to 0, it means bad relation or no relation
### If close to 0.5, it means moderate relation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(corr, annot=True)
plt.show()

# %%
titanic=pd.read_csv("I:/Data Science/Eduonix/Instructor - Prema Latha/Datasets-main/titanic-training-data.csv")

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic
## Problem Statement whether a passenger is survived or not

# %%
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 496          497         1       1  Eustis, Miss. Elizabeth Mussey  female
# 84            85         1       2             Ilett, Miss. Bertha  female
# 711          712         0       1              Klaber, Mr. Herman    male
# 191          192         0       2           Carbines, Mr. William    male
# 360          361         0       3              Skoog, Mr. Wilhelm    male
# 107          108         1       3          Moss, Mr. Albert Johan    male
# 509          510         1       3                  Lang, Mr. Fang    male
# 613          614         0       3                Horgan, Mr. John    male
# 723          724         0       2         Hodges, Mr. Henry Price    male
# 847          848         0       3              Markoff, Mr. Marin    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 496  54.0      1      0       36947  78.2667   D20        C
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanic.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
titanic["Ticket"].nunique()
# Out:
# 681

# %%
titanic["Survived"].nunique()
# Out:
# 2

# %%
titanic["Survived"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
titanic["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
titanic["SibSp"].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
titanic["Parch"].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
titanic["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sns.countplot(x="Survived", data=titanic)
plt.show()

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic=titanic.drop(columns=["PassengerId","Name","Ticket","Cabin"], axis=1)

# %%
sns.countplot(x="Survived",hue="Pclass", data=titanic)
plt.show()
## Majority of the passengers who were not able to survive are from Pclass 3

# %%
sns.countplot(x="Survived",hue="Sex", data=titanic)
plt.show()
## Majority of the passengers who're able to surive are female

# %%
sns.countplot(x="Survived",hue="Embarked", data=titanic)
plt.show()

# %%
titanic.hist(figsize=(10,10))
plt.show()

# %%
titanic.skew() ## Other way to check skewness
# Out:
# Survived    0.478523
# Pclass     -0.630548
# Age         0.389108
# SibSp       3.695352
# Parch       2.749117
# Fare        4.787317
# dtype: float64

# %%
sns.distplot(titanic["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.pairplot(titanic)
plt.show()

# %%
titanic_corr= titanic.corr()
titanic_corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(titanic_corr, annot=True, cmap="Blues")
plt.show()

# %%
sns.boxplot(x="Survived",y="Age" ,data=titanic)
plt.show()

# %%
sns.boxplot(x="Survived",y="Fare" ,data=titanic)
plt.show()
