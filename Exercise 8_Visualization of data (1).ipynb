# %% [markdown]
# # Exercise - Visualization of Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Step 2. Import the dataset from the AutoMPG dataset file. Assign it to a variable called mpg_df

# %%
mpg_df=pd.read_csv("I:/Data Science/Eduonix/Instructor - Prema Latha/Datasets-main/auto-mpg.csv")
mpg_df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# ### Step 3. Perform basic EDA to understand the structure of the data

# %%
mpg_df.shape
# Out:
# (398, 9)

# %%
mpg_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpg_df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
mpg_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
mpg_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
mpg_df.describe(include="all")
# Out:
#                mpg   cylinders  displacement horsepower       weight  \
# count   398.000000  398.000000    398.000000        398   398.000000
# unique         NaN         NaN           NaN         94          NaN
# top            NaN         NaN           NaN        150          NaN
# freq           NaN         NaN           NaN         22          NaN
# mean     23.514573    5.454774    193.425879        NaN  2970.424623
# std       7.815984    1.701004    104.269838        NaN   846.841774
# min       9.000000    3.000000     68.000000        NaN  1613.000000
# 25%      17.500000    4.000000    104.250000        NaN  2223.750000
# 50%      23.000000    4.000000    148.500000        NaN  2803.500000
# 75%      29.000000    8.000000    262.000000        NaN  3608.000000
# max      46.600000    8.000000    455.000000        NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %% [markdown]
# ### Step 4. Check and handle the missing values, if any.

# %%
mpg_df.isnull().sum() ## No missing values
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# ### Step 5. Create a plot to check the relationship between horsepower and acceleration. Note down your insight for the same. Beautify the graph using various customizations.

# %%
mpg_df["horsepower"].value_counts()
# Out:
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 61      1
# 93      1
# 148     1
# 152     1
# 82      1
# Name: horsepower, Length: 94, dtype: int64

# %%
sns.catplot(x="horsepower",y="acceleration",data=mpg_df)
plt.xlabel("Horsepower", fontsize=15, color="Red")
plt.ylabel("Acceleration", fontsize=15, color="Red")
plt.title("Relationship bet. horsepower and acceleration", fontsize=20, color="Brown")
plt.show()

# %%
## Swarm Plot
sns.catplot(x="horsepower",y="acceleration",kind="swarm",data=mpg_df)
plt.xlabel("Horsepower", fontsize=15, color="Red")
plt.ylabel("Acceleration", fontsize=15, color="Red")
plt.title("Relationship bet. horsepower and acceleration", fontsize=20, color="Brown")
plt.show()

# %%
## Insight: Majority of cars have less Horspower and Acceleration from the mean. Othwewise data looks symmetrical
## and there is no particular relation between two attributes

# %%
## Viloin Plot
sns.catplot(x="horsepower",y="acceleration",kind="violin",data=mpg_df)
plt.xlabel("Horsepower", fontsize=15, color="Red")
plt.ylabel("Acceleration", fontsize=15, color="Red")
plt.title("Relationship bet. horsepower and acceleration", fontsize=20, color="Brown")
plt.show()

# %%
## Box Plot
sns.catplot(x="horsepower",y="acceleration",kind="box",data=mpg_df)
plt.xlabel("Horsepower", fontsize=15, color="Red")
plt.ylabel("Acceleration", fontsize=15, color="Red")
plt.title("Relationship bet. horsepower and acceleration", fontsize=20, color="Brown")
plt.show()

# %% [markdown]
# ### Step 6. Generate subplots to display the histograms for acceleration, displacement and weight and kilometer_per_litre. Note down your insight for the same

# %%
kilometer_per_litre = 0.4251* mpg_df["mpg"]

# %%
type(kilometer_per_litre)
# Out:
# pandas.core.series.Series

# %%
plt.subplot(2,2,1)
plt.hist(mpg_df["acceleration"])
plt.title("Acceleration", color="Red")


plt.subplot(2,2,2)
plt.hist(mpg_df["displacement"])
plt.title("Displacement", color="Red")

plt.subplot(2,2,3)
plt.hist(mpg_df["weight"])
plt.title("Weight", color="Red")


plt.subplot(2,2,4)
plt.hist(kilometer_per_litre)
plt.title("kilometer Per Litre", color="Red")

plt.suptitle("Different Parameters of Cars", color="Black")

plt.subplots_adjust(left=0.1,
                    bottom=0,
                    right=0.9,
                    top=0.8,
                    wspace=0.7,
                    hspace=0.7)
plt.show()

# %%
## Insight: 
## Acceleration: Data is uniformly distributed
## Displacement: As the displacement increases the number of cars in the datset decresaes. Same is the scenario with
## Weight and Kilometer per litre

# %% [markdown]
# ### Step 7. Create a plot to check the relationship between displacement and weight for origin 2, color the datapoints based on no of cylinders. Note down your insight for the same and save the plot as an image file.

# %%
mpg_df.loc[mpg_df["origin"]==2,"displacement"]
# Out:
# pandas.core.series.Series

# %%
mpg_df.loc[mpg_df["origin"]==2,"weight"]
# Out:
# 19     1835
# 20     2672
# 21     2430
# 22     2375
# 23     2234
#        ...
# 354    2320
# 359    3230
# 360    3160
# 375    1980
# 394    2130
# Name: weight, Length: 70, dtype: int64

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\bansa'

# %%
sns.relplot(x=mpg_df.loc[mpg_df["origin"]==2,"displacement"], y=mpg_df.loc[mpg_df["origin"]==2,"weight"], hue="cylinders",
           data=mpg_df, palette="Set1")
plt.title("Relationship between Weight and Displacement")
plt.savefig("I:/Data Science/Eduonix/Instructor - Prema Latha/Exercise-main/Relation.png")
plt.show()

# %%
## Insight: 
## Weight, and displacment are directly proportional to each other
## Number of cylinders are 4 for all the cars having displacement till 120 and weight till 2750.

# %%
mpg_df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %% [markdown]
# ### Step 8. Display the frequency distribution of the Origin variable. Note down your insight for the same

# %%
## We should have Created distplot because Origin is a numerical type variable. But creating countplot because by looking
## at column values it seems it is categorical variable
sns.countplot(x="origin", data= mpg_df, palette="Set2")
plt.title("Frequency Dsitribution of Origin", color="red")
plt.show()

## Insight: Majority of the cars have origin as 1

# %% [markdown]
# ### Step 9. Check the relationship of multiple variables wrt kilometer_per_litre. Note down your insight for the same

# %%
kilometer_per_litre = 0.4251* mpg_df["mpg"]

# %%
mpg_df["kilometer_per_litre"]=kilometer_per_litre

# %%
mpg_df.dtypes
# Out:
# mpg                    float64
# cylinders                int64
# displacement           float64
# horsepower              object
# weight                   int64
# acceleration           float64
# model year               int64
# origin                   int64
# car name                object
# kilometer_per_litre    float64
# dtype: object

# %%
sns.relplot(x="cylinders",y="kilometer_per_litre", data=mpg_df, palette="Set2")
plt.title("Relationship between number of cylinders and KPL")
plt.show()

# %%
## Insight: As the number of cylinders increases, KPL decreases

# %%
sns.relplot(x="displacement",y="kilometer_per_litre", data=mpg_df, palette="Set2")
plt.title("Relationship between displacement and KPL")
plt.show()
## Insight: As the displacement increases, KPL decreases

# %%
sns.relplot(x="horsepower",y="kilometer_per_litre", data=mpg_df, palette="Set2")
plt.title("Relationship between Horsepower and KPL")
plt.show()
## Insight: There is no particular relationship between horsepower and KPL

# %%
sns.relplot(x="weight",y="kilometer_per_litre", data=mpg_df, palette="Set2")
plt.title("Relationship between Weight and KPL")
plt.show()
## Insight: As the weight increases, KPL decreases

# %%
sns.relplot(x="acceleration",y="kilometer_per_litre", data=mpg_df, palette="Set2")
plt.title("Relationship between acceleration and KPL")
plt.show()
## Insight: As the acceleration increases, KPL increases. But there are many outliers as well.

# %%
sns.catplot(x="origin",y="kilometer_per_litre", data=mpg_df, palette="Set2", kind="swarm")
plt.title("Relationship between Origin and KPL")
plt.show()
## Insight: As the Origin increases, average KPL increases.

# %%
sns.catplot(x="origin",y="kilometer_per_litre", data=mpg_df, palette="Set2", kind="violin")
plt.title("Relationship between Origin and KPL")
plt.show()

# %%
sns.catplot(x="origin",y="kilometer_per_litre", data=mpg_df, palette="Set2", kind="box")
plt.title("Relationship between Origin and KPL")
plt.show()

# %% [markdown]
# ### Step 10. Display the average weight based on no of cylinders present. Note down the insight for the same

# %%
mpg_df.groupby(mpg_df["cylinders"])["weight"].mean().plot()
plt.title("Average weight based on Number of Cylinders", color="red")
plt.ylabel("Average Weight")
plt.show()
## Insight" As the number of cylinder increases, average weight increases

# %%
sns.catplot(x="cylinders",y="weight", data=mpg_df, kind="violin")
plt.title("Average Weight based on Number of Cylinders", color="red")
plt.show()
## Insight: As the number of cylinder increases, average weight increases

# %% [markdown]
# ### Step 11. Check for the outliers in the dataset. Note down the insight for the same.

# %%
sns.boxplot(mpg_df["cylinders"])
plt.show()
## No outliers

# %%
mpg_df.dtypes
# Out:
# mpg                    float64
# cylinders                int64
# displacement           float64
# horsepower              object
# weight                   int64
# acceleration           float64
# model year               int64
# origin                   int64
# car name                object
# kilometer_per_litre    float64
# dtype: object

# %%
sns.boxplot(mpg_df["displacement"])
plt.show()
## No outliers

# %%
sns.boxplot(mpg_df["weight"])
plt.show()
## No outliers

# %%
sns.boxplot(mpg_df["acceleration"])
plt.show()
## We cam see below outliers in acceleration column

# %%
sns.boxplot(mpg_df["origin"])
plt.show()
## No outliers

# %% [markdown]
# ### Step 12. Plot the correlations for variables.

# %%
sns.pairplot(mpg_df)
plt.show()
